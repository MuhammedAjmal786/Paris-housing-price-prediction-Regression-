# %% [markdown]
# # **Problem statment**
# # **Paris House Price Prediction**

# %% [markdown]
# -- The Dataset is about house prices in Paris.
#
# -- This dataset provides a comprehensive collection of house details in Paris.
#
# -- This dataset have 10000 rows & 17 columns.
#
# -- All attributes are numeric variables.

# %% [markdown]
# **Column Heads:**
#
# -- **squareMeters:** squareMeters of the House.
#
# -- **numberOfRooms:** Numbers of room in the House.
#
# -- **hasYard:** Is House has Yard or not.
#
# -- **hasPool:** Is House has Pool or not.
#
# -- **floors:** Number of floor in the House.
#
# -- **cityCode:** Code of the city where House situating.
#
# -- **cityPartRange:** The higher the range, the more exclusive the neighbourhood is.
#
# -- **numPrevOwners:** Number of prevoious owners.
#
# -- **made:** Year the House made.
#
# -- **isNewBuilt:** Is House new or renovated.
#
# -- **hasStormProtector:** Is House has Storm Protector or not.
#
# -- **basement:** Basement square meters.
#
# -- **attic:** Attic square meteres.
#
# -- **garage:** Garage size
#
# -- **hasStorageRoom:** Is House has Storage Roomr or not.
#
# -- **hasGuestRoom:** Number of guest rooms in the House.
#
# -- **price:** Price of the House.

# %% [markdown]
# * **TARGET VARIABLE in this Dtaset is 'price'**

# %% [markdown]
# **Goals**:
#
#
# * **Market Analysis:**
# Identify Trends: By analyzing the dataset, you can identify trends in the Paris housing market, such as the average price per square meter, the most popular neighborhoods, or the relationship between property features and prices. This information can be valuable for real estate professionals, investors, and policymakers.
# Understand Factors Affecting Prices: The dataset enables you to explore the factors that influence house prices in Paris. For instance, you can determine the impact of features like the number of rooms, the presence of a yard or pool, or the location on the property's value.
#
# * **Investment Decisions:**
# Property Valuation: The dataset can be used to build predictive models that estimate the fair market value of houses in Paris. Investors can leverage these models to identify potentially undervalued properties and make informed investment decisions.
# Risk Assessment: By analyzing historical price trends and property characteristics, you can assess the risks associated with investing in specific neighborhoods or types of properties in Paris.
#
# * **Provide insights for Buyers and Sellers Pricing Strategy :** Both buyers and sellers can use the insights derived from the dataset to develop effective pricing strategies. Sellers can determine a competitive asking price for their property, while buyers can assess whether a property is priced fairly.
# Negotiation: The data can provide valuable information during price negotiations, helping both parties to make informed decisions.
#
# * **Research PurposesAcademic Research:** The dataset can be used by researchers to study various aspects of the housing market in Paris, such as the impact of economic factors, government policies, or urban development on house prices.
# To summarize:
#
# * The Paris Housing Dataset has the potential to provide valuable insights for a wide range of stakeholders, including real estate professionals, investors, buyers, sellers, and researchers. By analyzing the data and building predictive models, you can gain a better understanding of the Paris housing market and make more informed decisions.
# ---

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

#Ploating
import matplotlib.pyplot as plt
import seaborn as sns

#Emcoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# x-y split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

# Regression algorithms
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor  # Multi-layer perceptron regressor (MLP)

#MSE AND MAE
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt

#
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv('/kaggle/input/paris-housing-price-prediction/ParisHousing.csv')
df
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %% [markdown]
# # ***Understanding the data***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       10000 non-null  int64
#  1   numberOfRooms      10000 non-null  int64
#  2   hasYard            10000 non-null  int64
#  3   hasPool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   cityCode           10000 non-null  int64
#  6   cityPartRange      10000 non-null  int64
#  7   numPrevOwners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isNewBuilt         10000 non-null  int64
#  10  hasStormProtector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasStorageRoom     10000 non-null  int64
#  15  hasGuestRoom       10000 non-null  int64
# ...

# %%
df.shape
# Out:
# (10000, 17)

# %% [markdown]
# This dataset have 10000 rows & 17 columns

# %%
df.columns
# Out:
# Index(['squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
#        'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
#        'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
#        'hasGuestRoom', 'price'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                      count          mean           std      min         25%  \
# squareMeters       10000.0  4.987013e+04  2.877438e+04     89.0    25098.50
# numberOfRooms      10000.0  5.035840e+01  2.881670e+01      1.0       25.00
# hasYard            10000.0  5.087000e-01  4.999493e-01      0.0        0.00
# hasPool            10000.0  4.968000e-01  5.000148e-01      0.0        0.00
# floors             10000.0  5.027630e+01  2.888917e+01      1.0       25.00
# cityCode           10000.0  5.022549e+04  2.900668e+04      3.0    24693.75
# cityPartRange      10000.0  5.510100e+00  2.872024e+00      1.0        3.00
# numPrevOwners      10000.0  5.521700e+00  2.856667e+00      1.0        3.00
# made               10000.0  2.005488e+03  9.308090e+00   1990.0     1997.00
# isNewBuilt         10000.0  4.991000e-01  5.000242e-01      0.0        0.00
# hasStormProtector  10000.0  4.999000e-01  5.000250e-01      0.0        0.00
# ...

# %%
df.isnull().sum()
# Out:
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# dtype: int64

# %% [markdown]
# There is no Null values(Missing values) in the Dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no Duplicated rows in the Dataset

# %%
df.dtypes
# Out:
# squareMeters           int64
# numberOfRooms          int64
# hasYard                int64
# hasPool                int64
# floors                 int64
# cityCode               int64
# cityPartRange          int64
# numPrevOwners          int64
# made                   int64
# isNewBuilt             int64
# hasStormProtector      int64
# basement               int64
# attic                  int64
# garage                 int64
# hasStorageRoom         int64
# hasGuestRoom           int64
# price                float64
# dtype: object

# %% [markdown]
# All attributes are numeric variables.

# %% [markdown]
# # Data Cleanig & Feature Engineering

# %%
# Coping df into df1
df1=df.copy()

# %% [markdown]
# Dropping Columns 'isNewBuilt' & 'made' and adding column 'HouseAge.

# %% [markdown]
# 'isNewBuilt'Comparing with made it is contradicting

# %%
df1=df1.drop('isNewBuilt',axis=1)

# %%
df1['HouseAge']=2024-df1['made']
df1=df1.drop('made',axis=1)

# %%
df1.shape
# Out:
# (10000, 16)

# %%
df1
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  hasStormProtector  basement  attic  \
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# **Histogram for entire dataset**

# %%
df1.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# Distribution of **price**

# %%
sns.histplot(df1['price'], kde=True)
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Number of House that has **Yard**

# %%
plt.pie(df1['hasYard'].value_counts(),colors=['grey','g'],labels=['Didnt have Yard','Have Yard'],autopct='%1.1f%%')
plt.title('Number of House that has Yard')
plt.legend(bbox_to_anchor=(1.05, 1))
plt.show()

# %%
plt.bar(df1['hasYard'].value_counts().index,df1['hasYard'].value_counts().values,color=['grey','k'])
plt.title('Number of House that has Yard')
plt.ylabel('Number of House')

handles = [plt.Rectangle((0,0),1,1, color=c,ec="k") for c in ['grey', 'k']]
labels= ['Didnt have Yard','Have Yard']
plt.legend(handles, labels)

plt.show()

# %% [markdown]
# Number of House that has **Pool**

# %%
plt.pie(df1['hasPool'].value_counts(),colors=['grey','g'],labels=['Have Pool','Didnt have Pool'],autopct='%1.1f%%')
plt.title('Number of House that has Pool')
plt.legend(bbox_to_anchor=(1.05, 1))
plt.show()

# %%
plt.bar(df1['hasPool'].value_counts().index,df1['hasPool'].value_counts().values,color=['grey','k'])
plt.title('Number of House that has Pool')
plt.ylabel('Number of House')

handles = [plt.Rectangle((0,0),1,1, color=c,ec="k") for c in ['grey', 'k']]
labels= ['Have Pool','Didnt have Pool']
plt.legend(handles, labels)

plt.show()

# %% [markdown]
# Number of House that has **Storm Protector**

# %%
plt.pie(df1['hasStormProtector'].value_counts(),colors=['grey','g'],labels=['Have Storm Protector ','Didnt have Storm Protector'],autopct='%1.1f%%')
plt.title('Number of House that has StormProtector')
plt.legend(bbox_to_anchor=(1.05, 1))
plt.show()

# %%
plt.bar(df1['hasStormProtector'].value_counts().index,df1['hasStormProtector'].value_counts().values,color=['grey','k'])
plt.title('Number of House that has Storm Protector')
plt.ylabel('Number of House')

handles = [plt.Rectangle((0,0),1,1, color=c,ec="k") for c in ['grey', 'k']]
labels= ['Have Storm Protector ','Didnt have  Storm Protector']
plt.legend(handles, labels)

plt.show()

# %% [markdown]
# Number of House that has **Storage Room**

# %%
plt.pie(df1['hasStorageRoom'].value_counts(),colors=['grey','g'],labels=['Didnt have Storage Room ','Have Storage Room'],autopct='%1.1f%%')
plt.title('Number of House that has Storage Room')
plt.legend(bbox_to_anchor=(1.05, 1))
plt.show()

# %%
plt.bar(df1['hasStorageRoom'].value_counts().index,df1['hasStorageRoom'].value_counts().values,color=['grey','k'])
plt.title('Number of House that has Storage Room')
plt.ylabel('Number of House')

handles = [plt.Rectangle((0,0),1,1, color=c,ec="k") for c in ['grey', 'k']]
labels= ['Didnt have Storage Room ','Have  Storage Room']
plt.legend(handles, labels)

plt.show()

# %% [markdown]
# House Age

# %%
plt.pie(df1['HouseAge'].value_counts(),labels=df1['HouseAge'].unique(),autopct='%1.1f%%')
plt.title('HouseAge',loc='right')
plt.legend(bbox_to_anchor=(1.05, 1),ncols=2)
plt.show()

# %%
plt.hist(df1['HouseAge'],bins=10,color='grey',edgecolor='k')
plt.title('House Age')
plt.xlabel('House Age')
plt.ylabel('Frequency')
plt.show()

# %%
df1['HouseAge'].skew()
# Out:
# 0.0051570230575761185

# %% [markdown]
# numberOfRooms

# %%
plt.hist(df1['numberOfRooms'],bins=10,color='grey',edgecolor='k')
plt.title('Number of Rooms')
plt.xlabel('Number of Rooms')
plt.ylabel('Frequency')
plt.show()

# %%
df1['numberOfRooms'].skew()
# Out:
# 0.0187373417297422

# %% [markdown]
# floors

# %%
plt.hist(df1['floors'],bins=10,color='grey',edgecolor='k')
plt.title('Number of floors')
plt.xlabel('Number of floors')
plt.ylabel('Frequency')
plt.show()

# %%
df1['floors'].skew()
# Out:
# 0.0149306284350501

# %% [markdown]
# cityPartRange

# %%
plt.bar(df1['cityPartRange'].value_counts().index,df1['cityPartRange'].value_counts().values,color='grey',edgecolor='k')
plt.title('Number of cityPartRange')
plt.ylabel('Number of cityPartRange')
plt.show()

# %%
df1['cityPartRange'].skew()
# Out:
# -0.003339179103415519

# %% [markdown]
# numPrevOwners

# %%
plt.bar(df1['numPrevOwners'].value_counts().index,df1['numPrevOwners'].value_counts().values,color='grey',edgecolor='k')
plt.title('Number of PrevOwners')
plt.ylabel('Number of PrevOwners')
plt.show()

# %%
df1['numPrevOwners'].skew()
# Out:
# 0.0022448613864533107

# %% [markdown]
# hasGuestRoom

# %%
plt.bar(df1['hasGuestRoom'].value_counts().index,df1['hasGuestRoom'].value_counts().values,color='grey',edgecolor='k')
plt.title('Number of GuestRoom')
plt.ylabel('Number of GuestRoom')
plt.show()

# %%
df1['hasGuestRoom'].skew()
# Out:
# 0.007966378133967165

# %% [markdown]
# Relation between **squareMeters** & **price**

# %%
plt.plot(df1['squareMeters'],df1['price'],color='k')
plt.xlabel('square Meters')
plt.ylabel('Price')
plt.title('Relation between squareMeters & price')
plt.show()

# %% [markdown]
# Relation between **numberOfRooms** & **price**

# %%
cbys = df1.groupby('numberOfRooms')['price'].sum()
plt.bar(cbys.index,cbys.values,width=1,color='k',edgecolor='w')
# bars = plt.bar(cbys.index, cbys.values, color=['k', 'grey'])

plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.title('Relation between Number of Rooms & price')
# plt.legend([bars[0], bars[1]], ['Male', 'Female'])
plt.show()

# %% [markdown]
# Relation between **floors** & **price**

# %%
cbys = df1.groupby('floors')['price'].sum()
plt.bar(cbys.index,cbys.values,width=1,color='k',edgecolor='w')

plt.xlabel('Number Floors')
plt.ylabel('Price')
plt.title('Relation between floors & price')
plt.show()

# %% [markdown]
# Relation between **cityPartRange** & **price**

# %%
cbys = df1.groupby('cityPartRange')['price'].sum()
plt.bar(cbys.index,cbys.values,width=1,color='grey',edgecolor='k')

plt.xlabel('cityPartRange')
plt.ylabel('Price')
plt.title('Relation between cityPartRange & price')
plt.show()

# %% [markdown]
# Relation between **numPrevOwners** & **price**

# %%
cbys = df1.groupby('numPrevOwners')['price'].sum()
plt.bar(cbys.index,cbys.values,width=1,color='Grey',edgecolor='k')

plt.xlabel('Number of prevoious Owners')
plt.ylabel('Price')
plt.title('Relation between numPrevOwners & price')
plt.show()

# %% [markdown]
# Relation between **basement** & **price**

# %%
cbys = df1.groupby('basement')['price'].sum()
plt.bar(cbys.index,cbys.values,color='k')

plt.xlabel('Square meters of basement')
plt.ylabel('Price')
plt.title('Relation between basement & price')
plt.show()

# %% [markdown]
# Relation between **attic** & **price**

# %%
cbys = df1.groupby('attic')['price'].sum()
plt.bar(cbys.index,cbys.values,color='k')

plt.xlabel('Square meters of attic')
plt.ylabel('Price')
plt.title('Relation between attic & price')
plt.show()

# %% [markdown]
# Relation between **garage** & **price**

# %%
cbys = df1.groupby('garage')['price'].sum()
plt.bar(cbys.index,cbys.values,color='k')

plt.xlabel('Size of garage')
plt.ylabel('Price')
plt.title('Relation between garage & price')
plt.show()

# %% [markdown]
# Relation between **hasGuestRoom** & **price**

# %%
cbys = df1.groupby('hasGuestRoom')['price'].sum()
plt.bar(cbys.index,cbys.values,color='grey',edgecolor='k')

plt.xlabel('Number of Guest Room')
plt.ylabel('Price')
plt.title('Relation between hasGuestRoom & price')
plt.show()

# %% [markdown]
# Relation between **HouseAge** & **price**

# %%
cbys = df1.groupby('HouseAge')['price'].sum()
plt.bar(cbys.index,cbys.values,color='grey',edgecolor='k')

plt.xlabel('House Age')
plt.ylabel('Price')
plt.title('Relation between HouseAge & price')
plt.show()

# %% [markdown]
# # BoxPloat

# %%
plt.figure(figsize=(9,6))
sns.boxplot(df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **There is no outliers in the Dataset.**

# %% [markdown]
# # Correlation Analysis:

# %%
c=df1.corr()
c
# Out:
#                    squareMeters  numberOfRooms   hasYard   hasPool    floors  \
# squareMeters           1.000000       0.009573 -0.006650 -0.005594  0.001109
# numberOfRooms          0.009573       1.000000 -0.011240  0.017015  0.022244
# hasYard               -0.006650      -0.011240  1.000000  0.015514 -0.000883
# hasPool               -0.005594       0.017015  0.015514  1.000000 -0.004006
# floors                 0.001109       0.022244 -0.000883 -0.004006  1.000000
# cityCode              -0.001541       0.009040  0.006760  0.008072  0.002207
# cityPartRange          0.008758       0.008340  0.005023  0.014613 -0.004921
# numPrevOwners          0.016619       0.016766  0.004279 -0.006848  0.002463
# hasStormProtector      0.007480      -0.001656 -0.007598 -0.001001 -0.008566
# basement              -0.003960      -0.013990 -0.008558 -0.007268  0.006228
# attic                 -0.000588       0.012061 -0.003085 -0.011901 -0.000270
# ...

# %%
s=df1.corr()['price']
s.sort_values(ascending=False)
# Out:
# price                1.000000
# squareMeters         0.999999
# numPrevOwners        0.016619
# numberOfRooms        0.009591
# cityPartRange        0.008813
# hasStormProtector    0.007496
# HouseAge             0.007210
# floors               0.001654
# attic               -0.000600
# hasGuestRoom        -0.000644
# cityCode            -0.001539
# hasStorageRoom      -0.003485
# basement            -0.003967
# hasPool             -0.005070
# hasYard             -0.006119
# garage              -0.017229
# Name: price, dtype: float64

# %%
plt.figure(figsize=(25,8))
sns.heatmap(c,annot=True,cmap='Greens')
plt.title('Correlation heatmap')
plt.show()

# %% [markdown]
# # Feature Selection

# %%
x=df1[['squareMeters','numberOfRooms','hasYard','hasPool','floors','cityCode','cityPartRange','numPrevOwners','hasStormProtector','basement','attic','garage','hasStorageRoom','hasGuestRoom','HouseAge']]
y=df1['price']

# %% [markdown]
# # Data Splitting

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=12)

# %%
x_train
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 5951         52264             50        1        1      89     83169
# 6630          8746              3        1        0      39     84452
# 3240         24995             59        1        1      95     84138
# 5942         74477             22        1        1      27     61997
# 3789         33369             70        0        0       1     51828
# ...            ...            ...      ...      ...     ...       ...
# 3714         44219             15        1        1      82     46095
# 7409         52339             21        1        0      40     62344
# 3325         98149             91        0        1      24     50437
# 9606         90957             88        0        1      79     62257
# 5787         82900              3        0        1      11     59010
#
#       cityPartRange  numPrevOwners  hasStormProtector  basement  attic  \
# ...

# %%
y_train
# Out:
# 5951    5230980.6
# 6630     880925.8
# 3240    2511825.9
# 5942    7454179.4
# 3789    3337636.7
#           ...
# 3714    4436813.1
# 7409    5240271.0
# 3325    9820073.8
# 9606    9099516.3
# 5787    8295028.3
# Name: price, Length: 8000, dtype: float64

# %% [markdown]
# # Data Scaling

# %%
# x_train and x_test scaled with StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Initial Modeling & Hypothesis Testing:

# %%
# List of linear regression models to apply
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "Support Vector Regressor": SVR(),
    "K-Nearest Neighbors": KNeighborsRegressor(),
    "Neural Network": MLPRegressor(max_iter=1000)
}

# %%
# Function to evaluate model performance
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    return mae, rmse, r2

# %%
# Dictionary to store the results
results = {}

# %%
for name, model in models.items(): # When you call items() on a dictionary, returns a list of the dictionary’s key-value tuple pairs.
                                   # Here "name" represents the "key", and "model" represents the "value"
  if name in ["Support Vector Regressor", "Neural Network"]: # Standardised value is only applied to support vector regressor and Neural network
        # Apply scaling for models that need it
        model.fit(x_train_scaled, y_train)
        y_pred = model.predict(x_test_scaled)
  else:
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        # Compute evaluation metrics
  mae, rmse, r2 = evaluate_model(y_test, y_pred)
  results[name] = {"MAE": mae, "RMSE": rmse, "R²": r2}
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Convert results to a DataFrame for better visualization
results_df1= pd.DataFrame(results).T
print(results_df1)
# Out:
#                                    MAE          RMSE        R²
# Linear Regression         1.449408e+03  1.856982e+03  1.000000
# Ridge Regression          1.449398e+03  1.856974e+03  1.000000
# Lasso Regression          1.449447e+03  1.857004e+03  1.000000
# ElasticNet Regression     1.896570e+03  2.337611e+03  0.999999
# Decision Tree             4.422784e+03  5.572394e+03  0.999996
# Random Forest             3.178211e+03  3.941086e+03  0.999998
# Gradient Boosting         1.532076e+04  2.023711e+04  0.999952
# Support Vector Regressor  2.540265e+06  2.924412e+06 -0.004100
# K-Nearest Neighbors       6.020475e+04  7.569679e+04  0.999327
# Neural Network            4.865952e+06  5.624369e+06 -2.714049

# %% [markdown]
# **The best performing model is: Linear Regression**

# %% [markdown]
# # Model Generation

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
accuracy=r2_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9999995951299316

# %% [markdown]
# # Prediction

# %% [markdown]
# Method 1

# %%
# Define and assign values to the variables for the new house
new_square_meters = 75523
new_number_of_rooms = 4
new_has_yard = 1
new_has_pool = 0
new_floors = 2
new_city_code = 9373
new_city_part_range = 3
new_num_prev_owners = 1
new_has_storm_protector = 1
new_basement = 0
new_attic = 1
new_garage = 1
new_has_storage_room = 1
new_has_guest_room = 0
new_HouseAge = 4

# %%
# Create a DataFrame for the new house features
new_house_features = pd.DataFrame({
    'squareMeters': [new_square_meters],
    'numberOfRooms': [new_number_of_rooms],
    'hasYard': [new_has_yard],
    'hasPool': [new_has_pool],
    'floors': [new_floors],
    'cityCode': [new_city_code],
    'cityPartRange': [new_city_part_range],
    'numPrevOwners': [new_num_prev_owners],
    'hasStormProtector': [new_has_storm_protector],
    'basement': [new_basement],
    'attic': [new_attic],
    'garage': [new_garage],
    'hasStorageRoom': [new_has_storage_room],
    'hasGuestRoom': [new_has_guest_room],
    'HouseAge': [new_HouseAge]

})

# %%
predicted_price =model.predict(new_house_features)
print(f"The Predicted Price: € {predicted_price[0]:.2f}")
# Out:
# The Predicted Price: € 7556101.82

# %% [markdown]
# Methode 2

# %%
x_test
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 5669         87683             53        0        1      57     30308
# 8800         14074             85        1        1      78     18483
# 3205         42616             83        0        1      97     11070
# 8731         55752             48        1        0      42     32183
# 6412         69418              3        1        1      70     32221
# ...            ...            ...      ...      ...     ...       ...
# 794          41083             69        1        0      62     90286
# 142          16068             21        1        0      13     21716
# 275          24393             46        1        1      16     18507
# 8265         93180             91        1        1       3     10016
# 7950         96276             35        1        0      81      5997
#
#       cityPartRange  numPrevOwners  hasStormProtector  basement  attic  \
# ...

# %%
y_test
# Out:
# 5669    8774909.3
# 8800    1421626.3
# 3205    4272292.6
# 8731    5580831.9
# 6412    6951279.2
#           ...
# 794     4114499.7
# 142     1611707.1
# 275     2449464.9
# 8265    9323693.2
# 7950    9637443.6
# Name: price, Length: 2000, dtype: float64

# %%
input_data=(87683,  53  ,0  ,1, 57, 30308   ,3, 3   ,0, 1759,   1003,   850,    1,  7   ,31)

input_data_as_numpy_array=np.asarray(input_data)

input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

# std_data= scaler.transform(input_data_reshaped)

prediction=model.predict(input_data_reshaped)

print(f"The Predicted Price: € {prediction}")
# Out:
# The Predicted Price: € [8774981.13865642]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #**Documentation and Reporting**
#
#
# ## **Paris House Price Prediction** Project Report
# **1. Problem Statement:**
#
# - This dataset provides a comprehensive collection of house details in Paris.
# -
# The primary objective is to build a model that accurately predicts the Price of Paris House based on its features.
#
# **2.Libraries:**
# - import required Libraries.
#
# **3. Data Understanding:**
# - The dataset has 10000 rows & 17 columns.
# - Features include: squareMeters,	numberOfRooms	,hasYard	,hasPool,	floors,	cityCode	,cityPartRange	,numPrevOwners,	made	,isNewBuilt,	hasStormProtector,	basement	,attic,	garage,	hasStorageRoom,	hasGuestRoom &	price.
# - There is no Null values(Missing values) in the Dataset.
# - There is no Duplicated rows in the Dataset.
# - All attributes are numeric variables.
#
# **4. Data Cleanig & Feature Engineering:**
# - Droped Columns 'isNewBuilt' & 'made'.
# - Added column 'HouseAge'.
#
# **5. Data Visualization:**
# - Histogram were created for entire dataset to understand their distribution.
# - Histograms were created for Price,HouseAge,numberOfRooms,floors to understand their distribution.
# - Pie chart created for hasYard,hasPool,hasStormProtector,hasStorageRoom,HouseAge to understand their percent for each value.
# - Barplot created for hasYard,hasPool,hasStormProtector,hasStorageRoom,cityPartRange,numPrevOwners,hasGuestRoom to understand their distribution.
# - Lineplot crated for understand Relation between squareMeters & price.
# - Barplot created for Relation between all features  & price with groupby.
#
# **6.Boxplot**
# - Boxplot created for every features.
# - There is no outliers in the Dataset.
#
# **7. Correlation Analysis:**
# - Correlation Analysis: a heatmap of the correlation matrix revealed the relationships between the variables.
#
# **8. Feature Selection**
# - Target column stored in y variable.
# - Other features stored in x variable.
#
# **9. Data Splitting**
# - split x_train, x_test, y_train and y_test.
#
# **10. Data Scaling:**
# - x_train and x_test were scaled using StandardScaler.
#
# **11. Initial Modeling & Hypothesis Testing:**
# -- Multiple regression models were tested:-
# * Linear Regression.
# * Ridge Regression.
# * Lasso Regression.
# * ElasticNet Regression.
# * Decision Tree Regression.
# * Random Forest Regression.
# * Gradient Boosting Regression.
# * Support Vector Regression.
# * K-Nearest Neighbors Regression.
# * Neural Network Regression.
#
# --  **Linear Regression** has given the best result with accuracy around 0.9999995951299316 and it was chosen as the final model.
#
# **12.Model Generation:**
#
# -- Evaluation metrics included Mean Absolute Error,Mean Squared Error,Root Mean Squared Error
#
# - Mean Absolute Error: 1.449408e+03
# - Root Mean Squared Error:  1.856982e+03
# - R2 score:1.000000
#
# **13.Prediction**
# - Try prediction in two methods.
# - In both method the prediction is amazing.
#
# **THANK YOU**
